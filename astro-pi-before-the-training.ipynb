# %% [markdown]
# # Part 1: Before the training
#
# Great to see that you are planning to code along during the Advanced Astro Pi Training. To make the code along session run smoothly, we ask you to complete the following tasks before the training: <br>
# <ol>
#     <li>Download historic photo's: <a href="https://rpf.io/p/en/astropi-iss-speed-go">https://rpf.io/p/en/astropi-iss-speed-go</a>.</li>
#     <li>Install Thonny: <a href="https://thonny.org/">https://thonny.org/</a>.</li>
#     <li>Install plugin: Open Thonny, Click on <b>Tools > Manage plug-ins…</b>, and search for <b>thonny-astro-pi-replay</b> and click install.</li>
#     <li>Install package: Click on <b>Tools > Manage packages…</b>, and search for <b>astro-pi-replay</b> and click install.</li>
#     <li>You need to restart Thonny to make the plugin and package installation complete.</li>
#     <li>Look if the Astro Pi Replay tool appears when you click on <b>Run</b> in the menu.</li>
#
# </ol>
#
#
#  ![run-button.PNG](attachment:run-button.PNG)
#
#
# <br>
# <br>
# <br>
# <br>
#
# <ol start="7">
#     <li>Test if the Astro Pi Replay tool works by copying the code below and running it by clicking on <b>Run</b> in the menu, then clicking on <b>Astro-Pi-Replay</b>. Repeat step 3 to 5 if it doesn't work. If you don't manage to make it work, please send an email and we'll try to find a solution together.</li>
# </ol>

# %%
print("Hello world")

# %% [markdown]
# This should produce the following output:
# <br>
#
# ![output-hello-world.JPG](attachment:output-hello-world.JPG)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# If this works then you are ready to code along during the training :)
#
# We recommend using two screens during the training (one for teams and one for Thonny).
